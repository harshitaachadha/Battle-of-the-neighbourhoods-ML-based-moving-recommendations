# %% [markdown]
# # Coursera Capstone project : week 1

# %% [markdown]
# This notebook will be used to construct the project titled "The battle of the neighbourhoods" as part of the IBM Data Science proffessional certification program. It will contain all the relvant details pertaining to the same.

# %%
# Importing the pandas library as pd
import pandas as pd

# %%
# Importing the numpy library as np
import numpy as np

# %%
# Printing the required statement
print('Hello capstone project!')
# Out:
# Hello capstone project!
